# %% [markdown]
# # Summarize PDTC Metadata
# ## Date: 2022-02-15
# ## Author: Jeffrey Grover
# **Purpose:** Summarize the improvement in the PDTC Metadata.

# %% [markdown]
# ### Load libraries

# %%
library(tidyverse)

# %% [markdown]
# ### Load the metadata
# Since it's been fixed. What's the missing data situation look like?

# %%
pdtc_metadata <- read_csv('../2022-02-09_pdxnet_pdtc_pdmr_portal_ids/2022-02-15_pdtc_metadata_cleaned.csv')

nrow(pdtc_metadata)
head(pdtc_metadata)
# Out:
# New names:
# * `` -> ...1
#
# Rows: 2180 Columns: 26
#
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (24): contributor, file_name, patient_id, model_id, tumor_id, case_id, s...
# dbl  (2): ...1, paired_end
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] 2180
#   ...1 contributor file_name                               patient_id model_id
# 1 1    BCM         LZML_37246_NoIndex_L00X_R1_001.fastq.gz 24452      BCM-0002
# 2 2    BCM         LZML_37246_NoIndex_L00X_R2_001.fastq.gz 24452      BCM-0002
# 3 3    BCM         ML6065_GATCAGCG_L00X_R1_001.fastq.gz    2219       BCM-0046
# 4 4    BCM         ML6065_GATCAGCG_L00X_R2_001.fastq.gz    2219       BCM-0046
# 5 5    BCM         ML6061_CAGATCTG_L00X_R1_001.fastq.gz    24561      BCM-0104
# 6 6    BCM         ML6061_CAGATCTG_L00X_R2_001.fastq.gz    24561      BCM-0104
#   tumor_id    case_id sample_id sample_type experimental_strategy ⋯
# 1 2011012-2   NA      BCM-0002  PDX         RNA-Seq               ⋯
# 2 2011012-2   NA      BCM-0002  PDX         RNA-Seq               ⋯
# 3 2011012-46  NA      BCM-0046  PDX         RNA-Seq               ⋯
# 4 2011012-46  NA      BCM-0046  PDX         RNA-Seq               ⋯
# 5 2011012-104 NA      BCM-0104  PDX         RNA-Seq               ⋯
# 6 2011012-104 NA      BCM-0104  PDX         RNA-Seq               ⋯
#   access_level data_category       data_format data_type platform is_ffpe
# 1 Controlled   Raw Sequencing Data fastq.gz    Raw Reads Illumina FALSE
# 2 Controlled   Raw Sequencing Data fastq.gz    Raw Reads Illumina FALSE
# 3 Controlled   Raw Sequencing Data fastq.gz    Raw Reads Illumina FALSE
# 4 Controlled   Raw Sequencing Data fastq.gz    Raw Reads Illumina FALSE
# 5 Controlled   Raw Sequencing Data fastq.gz    Raw Reads Illumina FALSE
# 6 Controlled   Raw Sequencing Data fastq.gz    Raw Reads Illumina FALSE
#   passage body_location disease_type              comment
# 1 Unknown Breast        Invasive breast carcinoma NA
# 2 Unknown Breast        Invasive breast carcinoma NA
# 3 Unknown Breast        Invasive breast carcinoma NA
# 4 Unknown Breast        Invasive breast carcinoma NA
# 5 Unknown Breast        Invasive breast carcinoma NA
# 6 Unknown Breast        Invasive breast carcinoma NA

# %%
# Define function to summarize missing fields

summarize_missing_fields <- function(df) {
    colSums((is.na(df) | (df == 'Unknown') | (df == '?'))) %>% as.data.frame()
}

# %%
# How many NAs are there for the most important columns?


summarize_missing_fields(pdtc_metadata)
# Out:
#                       .
# ...1                     0
# contributor              0
# file_name                0
# patient_id              26
# model_id               870
# tumor_id              1422
# case_id                602
# sample_id                0
# sample_type              0
# experimental_strategy    0
# gender                  48
# paired_end               0
# capture_kit             26
# capture_assembly      1570
# availability             0
# public                   0
# access_level             0
# data_category            0
# data_format              0
# data_type                0
# platform                 0
# is_ffpe               1714
# passage               1174
# body_location           80
# disease_type            80
# comment               2144

# %% [markdown]
# Note: Some of these *should* have NAs in them. For example, "passage" is not meaningful for primary tumor samples.

# %%
# Break down by PDTC

pdtc_metadata <- pdtc_metadata %>% group_split(contributor)
names(pdtc_metadata) <- c('BCM', 'HCI', 'MDACC', 'UC Davis', 'WISTAR', 'WUSTL')

pdtc_metadata %>% map(head, 1)
# Out:
# $BCM
# # A tibble: 1 × 26
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1     1 BCM         LZML_37246_N… 24452      BCM-0002 2011012… NA      BCM-0002
# # … with 18 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>, data_category <chr>,
# #   data_format <chr>, data_type <chr>, platform <chr>, is_ffpe <chr>,
# #   passage <chr>, body_location <chr>, disease_type <chr>, comment <chr>
#
# $HCI
# # A tibble: 1 × 26
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1   209 HCI         14990X12_HCI… HCI001     NA       NA       HCI001  14990X12
# # … with 18 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>, data_category <chr>,
# #   data_format <chr>, data_type <chr>, platform <chr>, is_ffpe <chr>,
# #   passage <chr>, body_location <chr>, disease_type <chr>, comment <chr>
#
# $MDACC
# # A tibble: 1 × 26
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1   455 MDACC       BFang-LungPD… TC211      NA       NA       TC211   TC211W
# # … with 18 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>, data_category <chr>,
# #   data_format <chr>, data_type <chr>, platform <chr>, is_ffpe <chr>,
# #   passage <chr>, body_location <chr>, disease_type <chr>, comment <chr>
#
# $`UC Davis`
# # A tibble: 1 × 26
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1   873 UC Davis    BL0269F404_P… BL0269F    BL0269F  BL0269F  BL0269F BL0269F
# # … with 18 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>, data_category <chr>,
# #   data_format <chr>, data_type <chr>, platform <chr>, is_ffpe <chr>,
# #   passage <chr>, body_location <chr>, disease_type <chr>, comment <chr>
#
# $WISTAR
# # A tibble: 1 × 26
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1   921 WISTAR      wm3907n_R1.f… WM3907     wm3907n  NA       NA      wm3907n
# # … with 18 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>, data_category <chr>,
# #   data_format <chr>, data_type <chr>, platform <chr>, is_ffpe <chr>,
# #   passage <chr>, body_location <chr>, disease_type <chr>, comment <chr>
#
# $WUSTL
# # A tibble: 1 × 26
#    ...1 contributor file_name   patient_id  model_id  tumor_id case_id sample_id
#   <dbl> <chr>       <chr>       <chr>       <chr>     <chr>    <chr>   <chr>
# 1  1303 WUSTL       172845-121… PDMR-172845 172845-1… 121-T    PDMR-1… 172845-1…
# # … with 18 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>, data_category <chr>,
# #   data_format <chr>, data_type <chr>, platform <chr>, is_ffpe <chr>,
# #   passage <chr>, body_location <chr>, disease_type <chr>, comment <chr>

# %%
# Break down the missing metadata fields by PDTC

pdtc_metadata %>% map(summarize_missing_fields)
# Out:
# $BCM
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id              2
# model_id                0
# tumor_id               16
# case_id               208
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                 20
# paired_end              0
# capture_kit            26
# capture_assembly      208
# availability            0
# public                  0
# access_level            0
# data_category           0
# data_format             0
# data_type               0
# platform                0
# is_ffpe               124
# passage               208
# body_location          48
# disease_type           48
# comment               208
#
# $HCI
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id              0
# model_id              246
# tumor_id              246
# case_id                 0
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                  0
# paired_end              0
# capture_kit             0
# capture_assembly       48
# availability            0
# public                  0
# access_level            0
# data_category           0
# data_format             0
# data_type               0
# platform                0
# is_ffpe               246
# passage               144
# body_location           8
# disease_type            8
# comment               224
#
# $MDACC
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id             12
# model_id              264
# tumor_id              418
# case_id                12
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                 12
# paired_end              0
# capture_kit             0
# capture_assembly       12
# availability            0
# public                  0
# access_level            0
# data_category           0
# data_format             0
# data_type               0
# platform                0
# is_ffpe               418
# passage               272
# body_location          12
# disease_type           12
# comment               404
#
# $`UC Davis`
#                        .
# ...1                   0
# contributor            0
# file_name              0
# patient_id             0
# model_id               0
# tumor_id               0
# case_id                0
# sample_id              0
# sample_type            0
# experimental_strategy  0
# gender                 0
# paired_end             0
# capture_kit            0
# capture_assembly      48
# availability           0
# public                 0
# access_level           0
# data_category          0
# data_format            0
# data_type              0
# platform               0
# is_ffpe               48
# passage                0
# body_location          0
# disease_type           0
# comment               48
#
# $WISTAR
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id             12
# model_id                0
# tumor_id              382
# case_id               382
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                 16
# paired_end              0
# capture_kit             0
# capture_assembly      382
# availability            0
# public                  0
# access_level            0
# data_category           0
# data_format             0
# data_type               0
# platform                0
# is_ffpe                 0
# passage               190
# body_location          12
# disease_type           12
# comment               382
#
# $WUSTL
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id              0
# model_id              360
# tumor_id              360
# case_id                 0
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                  0
# paired_end              0
# capture_kit             0
# capture_assembly      872
# availability            0
# public                  0
# access_level            0
# data_category           0
# data_format             0
# data_type               0
# platform                0
# is_ffpe               878
# passage               360
# body_location           0
# disease_type            0
# comment               878

# %% [markdown]
# ### How many missing metadata fields were there originally?

# %%
# Load the original metadata

original_pdtc_metadata <- read_csv('../2022-02-09_pdxnet_pdtc_pdmr_portal_ids/2022-02-09_pdxnet_portal_pdtc_files.csv')

nrow(original_pdtc_metadata)
head(original_pdtc_metadata)
# Out:
# New names:
# * `` -> ...1
#
# Rows: 2822 Columns: 29
#
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (23): contributor, file_name, patient_id, model_id, tumor_id, case_id, s...
# dbl  (4): ...1, paired_end, created_datetime, file_size
# lgl  (2): is_ffpe, investigation
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] 2822
#   ...1 contributor file_name                               patient_id model_id
# 1 1    BCM         LZML_37246_NoIndex_L00X_R1_001.fastq.gz 24452      BCM-0002
# 2 2    BCM         LZML_37246_NoIndex_L00X_R2_001.fastq.gz 24452      BCM-0002
# 3 3    BCM         ML6065_GATCAGCG_L00X_R1_001.fastq.gz    2219       BCM-0046
# 4 4    BCM         ML6065_GATCAGCG_L00X_R2_001.fastq.gz    2219       BCM-0046
# 5 5    BCM         ML6061_CAGATCTG_L00X_R1_001.fastq.gz    24561      BCM-0104
# 6 6    BCM         ML6061_CAGATCTG_L00X_R2_001.fastq.gz    24561      BCM-0104
#   tumor_id    case_id sample_id sample_type experimental_strategy ⋯ data_format
# 1 2011012-2   NA      BCM-0002  PDX         RNA-Seq               ⋯ FASTQ.GZ
# 2 2011012-2   NA      BCM-0002  PDX         RNA-Seq               ⋯ FASTQ.GZ
# 3 2011012-46  NA      BCM-0046  PDX         RNA-Seq               ⋯ FASTQ.GZ
# 4 2011012-46  NA      BCM-0046  PDX         RNA-Seq               ⋯ FASTQ.GZ
# 5 2011012-104 NA      BCM-0104  PDX         RNA-Seq               ⋯ FASTQ.GZ
# 6 2011012-104 NA      BCM-0104  PDX         RNA-Seq               ⋯ FASTQ.GZ
#   data_type platform is_ffpe file_size   passage disease_type comment
# 1 Raw Reads Illumina FALSE   20656964441 NA      Breast       NA
# 2 Raw Reads Illumina FALSE   21093643386 NA      Breast       NA
# 3 Raw Reads Illumina FALSE   22027304876 NA      Breast       NA
# 4 Raw Reads Illumina FALSE   22027304876 NA      Breast       NA
# 5 Raw Reads Illumina FALSE   17927987899 NA      Breast       NA
# 6 Raw Reads Illumina FALSE   18002109303 NA      Breast       NA
#   investigation disease_detail
# 1 NA            Invasive breast carcinoma
# 2 NA            Invasive breast carcinoma
# 3 NA            Invasive breast carcinoma
# 4 NA            Invasive breast carcinoma
# 5 NA            Invasive breast carcinoma
# 6 NA            Invasive breast carcinoma

# %%
# NAs and missing data originally?

summarize_missing_fields(original_pdtc_metadata)
# Out:
#                       .
# ...1                     0
# contributor              0
# file_name                0
# patient_id              26
# model_id              1515
# tumor_id              2067
# case_id                602
# sample_id                0
# sample_type              0
# experimental_strategy    0
# gender                 436
# paired_end              17
# capture_kit            821
# capture_assembly      2205
# availability             0
# public                  48
# access_level          1345
# created_datetime      2711
# data_category         1345
# data_format           1297
# data_type             1297
# platform               124
# is_ffpe               2356
# file_size             1403
# passage               1631
# disease_type           515
# comment               2776
# investigation         2822
# disease_detail         515

# %%
# Break down by PDTC

original_pdtc_metadata <- original_pdtc_metadata %>% group_split(contributor)
names(original_pdtc_metadata) <- c('BCM', 'HCI', 'MDACC', 'UC Davis', 'WISTAR', 'WUSTL')

original_pdtc_metadata %>% map(head, 1)
# Out:
# $BCM
# # A tibble: 1 × 29
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1     1 BCM         LZML_37246_N… 24452      BCM-0002 2011012… NA      BCM-0002
# # … with 21 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>,
# #   created_datetime <dbl>, data_category <chr>, data_format <chr>,
# #   data_type <chr>, platform <chr>, is_ffpe <lgl>, file_size <dbl>,
# #   passage <chr>, disease_type <chr>, comment <chr>, investigation <lgl>,
# #   disease_detail <chr>
#
# $HCI
# # A tibble: 1 × 29
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1   209 HCI         14990X12_HCI… HCI001     NA       NA       HCI001  14990X12
# # … with 21 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>,
# #   created_datetime <dbl>, data_category <chr>, data_format <chr>,
# #   data_type <chr>, platform <chr>, is_ffpe <lgl>, file_size <dbl>,
# #   passage <chr>, disease_type <chr>, comment <chr>, investigation <lgl>,
# #   disease_detail <chr>
#
# $MDACC
# # A tibble: 1 × 29
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1  1100 MDACC       BFang-LungPD… TC211      NA       NA       TC211   TC211W
# # … with 21 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>,
# #   created_datetime <dbl>, data_category <chr>, data_format <chr>,
# #   data_type <chr>, platform <chr>, is_ffpe <lgl>, file_size <dbl>,
# #   passage <chr>, disease_type <chr>, comment <chr>, investigation <lgl>,
# #   disease_detail <chr>
#
# $`UC Davis`
# # A tibble: 1 × 29
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1  1518 UC Davis    BL0269F404_P… BL0269F    BL0269F  BL0269F  BL0269F BL0269F
# # … with 21 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>,
# #   created_datetime <dbl>, data_category <chr>, data_format <chr>,
# #   data_type <chr>, platform <chr>, is_ffpe <lgl>, file_size <dbl>,
# #   passage <chr>, disease_type <chr>, comment <chr>, investigation <lgl>,
# #   disease_detail <chr>
#
# $WISTAR
# # A tibble: 1 × 29
#    ...1 contributor file_name     patient_id model_id tumor_id case_id sample_id
#   <dbl> <chr>       <chr>         <chr>      <chr>    <chr>    <chr>   <chr>
# 1  1566 WISTAR      wm3907n_R1.f… WM3907     wm3907n  NA       NA      wm3907n
# # … with 21 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>,
# #   created_datetime <dbl>, data_category <chr>, data_format <chr>,
# #   data_type <chr>, platform <chr>, is_ffpe <lgl>, file_size <dbl>,
# #   passage <chr>, disease_type <chr>, comment <chr>, investigation <lgl>,
# #   disease_detail <chr>
#
# $WUSTL
# # A tibble: 1 × 29
#    ...1 contributor file_name   patient_id  model_id  tumor_id case_id sample_id
#   <dbl> <chr>       <chr>       <chr>       <chr>     <chr>    <chr>   <chr>
# 1  1948 WUSTL       172845-121… PDMR-172845 172845-1… 121-T    PDMR-1… 172845-1…
# # … with 21 more variables: sample_type <chr>, experimental_strategy <chr>,
# #   gender <chr>, paired_end <dbl>, capture_kit <chr>, capture_assembly <chr>,
# #   availability <chr>, public <chr>, access_level <chr>,
# #   created_datetime <dbl>, data_category <chr>, data_format <chr>,
# #   data_type <chr>, platform <chr>, is_ffpe <lgl>, file_size <dbl>,
# #   passage <chr>, disease_type <chr>, comment <chr>, investigation <lgl>,
# #   disease_detail <chr>

# %%
# Get the number of missing metadata fields from the original metadata

original_pdtc_metadata %>% map(summarize_missing_fields)
# Out:
# $BCM
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id              2
# model_id                0
# tumor_id               16
# case_id               208
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                 42
# paired_end              0
# capture_kit           124
# capture_assembly      208
# availability            0
# public                  0
# access_level            0
# created_datetime      124
# data_category           0
# data_format             0
# data_type               0
# platform              124
# is_ffpe               124
# file_size              46
# passage               208
# disease_type           98
# comment               208
# investigation         208
# disease_detail         98
#
# $HCI
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id              0
# model_id              891
# tumor_id              891
# case_id                 0
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                  0
# paired_end              8
# capture_kit           697
# capture_assembly      683
# availability            0
# public                  0
# access_level          891
# created_datetime      891
# data_category         891
# data_format           891
# data_type             891
# platform                0
# is_ffpe               891
# file_size             891
# passage               779
# disease_type            8
# comment               859
# investigation         891
# disease_detail          8
#
# $MDACC
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id             12
# model_id              264
# tumor_id              418
# case_id                12
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                 12
# paired_end              0
# capture_kit             0
# capture_assembly       12
# availability            0
# public                  0
# access_level          406
# created_datetime      418
# data_category         406
# data_format           406
# data_type             406
# platform                0
# is_ffpe               418
# file_size             418
# passage               272
# disease_type           12
# comment               404
# investigation         418
# disease_detail         12
#
# $`UC Davis`
#                        .
# ...1                   0
# contributor            0
# file_name              0
# patient_id             0
# model_id               0
# tumor_id               0
# case_id                0
# sample_id              0
# sample_type            0
# experimental_strategy  0
# gender                 0
# paired_end             0
# capture_kit            0
# capture_assembly      48
# availability           0
# public                48
# access_level          48
# created_datetime      48
# data_category         48
# data_format            0
# data_type              0
# platform               0
# is_ffpe               48
# file_size             48
# passage                0
# disease_type           0
# comment               48
# investigation         48
# disease_detail         0
#
# $WISTAR
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id             12
# model_id                0
# tumor_id              382
# case_id               382
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                382
# paired_end              0
# capture_kit             0
# capture_assembly      382
# availability            0
# public                  0
# access_level            0
# created_datetime      370
# data_category           0
# data_format             0
# data_type               0
# platform                0
# is_ffpe                 0
# file_size               0
# passage                12
# disease_type          382
# comment               382
# investigation         382
# disease_detail        382
#
# $WUSTL
#                         .
# ...1                    0
# contributor             0
# file_name               0
# patient_id              0
# model_id              360
# tumor_id              360
# case_id                 0
# sample_id               0
# sample_type             0
# experimental_strategy   0
# gender                  0
# paired_end              9
# capture_kit             0
# capture_assembly      872
# availability            0
# public                  0
# access_level            0
# created_datetime      860
# data_category           0
# data_format             0
# data_type               0
# platform                0
# is_ffpe               875
# file_size               0
# passage               360
# disease_type           15
# comment               875
# investigation         875
# disease_detail         15

# %% [markdown]
# At this point we only have 80 missing disease information (vs over 500 originally) and 26 missing capture_kit info. Passage is problematic. Some that are missing gender/sex information are probably ones where the patient did not provide it. Also, all unmerged lanes and non-fastqs have been removed and replaced with their merged or fastq-converted counterparts. Unnecessary metadata fields like `created_datetime` and `file_size` were removed. `disease_type` was renamed to `body_location` and `disease_detail` changed to `disease_type` to match the fields for the PDMR.
#
# As before, library prep kits for RNAseq are also included in the `capture_kit` column.
#
# Other changes include using "Unknown" for missing data in most fields, and NA where they do not apply. Such as primary tumors getting NA in passage or model ID, but samples without known `disease_type` getting "Unknown." All files were set to "Controlled" access unless already public by the PDTC according to their metadata.
#
# Many other missing fields here and there pulled from model info, metadata included in the center's dbGaP submission, or in some cases from the metadata on the CGC.
#
# This metadata can now also be applied to all these files on the CGC. That will also indicate files on the CGC that are not included in this list, if any.
#
# At this time, I don't think it will be possible to get the remaining missing info without going back to the individual PDTCs for that information.
